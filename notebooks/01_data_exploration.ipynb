# %%
import polars as pl
from src.wr_predictor.data_loader import load_player_weekly_stats
from src.wr_predictor.filters import filter_wide_receivers


"""
quick interactive exploration of raw WR data
"""

data_frame = load_player_weekly_stats([2023, 2024])
wr_data_frame = filter_wide_receivers(data_frame)

print(wr_data_frame.shape)
wr_data_frame.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import polars as pl
#       2 from src.wr_predictor.data_loader import load_player_weekly_stats
#       3 from src.wr_predictor.filters import filter_wide_receivers
#
# ModuleNotFoundError: No module named 'polars'
